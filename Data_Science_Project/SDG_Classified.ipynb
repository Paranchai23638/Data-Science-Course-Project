# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util
import torch

print("🚀 Starting SDG Classification (Unsupervised AI)...")

# 1. Load Data

try:
    df = pd.read_csv('CSV_Files\papers_all_years.csv')
except:
    df = pd.read_csv('CSV_Files\papers_all_years.csv')


df = df[['title', 'year', 'journal', 'subject_areas_str']].dropna(subset=['title'])
print(f"   -> Loaded {len(df)} papers")

print("🚀 Starting SDG Classification (Unsupervised AI)...")

try:
    df = pd.read_csv('CSV_Files\papers_all_years.csv')
    print(f"   -> Original CSV rows: {len(df)}") 
except:
    print("❌ Error: File not found")
    exit()

df = df[['title', 'year', 'journal', 'subject_areas_str']].dropna(subset=['title'])

df = df.drop_duplicates(subset=['title'])

df = df[df['title'].str.len() > 5] 

df = df.reset_index(drop=True) 

print(f"   -> Cleaned rows to process: {len(df)}") 

sdg_definitions = {
    'SDG 1': 'No Poverty: End poverty in all its forms everywhere, economic growth, social protection.',
    'SDG 2': 'Zero Hunger: End hunger, achieve food security and improved nutrition and promote sustainable agriculture.',
    'SDG 3': 'Good Health and Well-being: Ensure healthy lives and promote well-being for all at all ages, medicine, disease, virus, mental health.',
    'SDG 4': 'Quality Education: Ensure inclusive and equitable quality education and promote lifelong learning opportunities for all.',
    'SDG 5': 'Gender Equality: Achieve gender equality and empower all women and girls.',
    'SDG 6': 'Clean Water and Sanitation: Ensure availability and sustainable management of water and sanitation for all.',
    'SDG 7': 'Affordable and Clean Energy: Ensure access to affordable, reliable, sustainable and modern energy for all, electricity, renewable.',
    'SDG 8': 'Decent Work and Economic Growth: Promote sustained, inclusive and sustainable economic growth, full and productive employment.',
    'SDG 9': 'Industry, Innovation and Infrastructure: Build resilient infrastructure, promote inclusive and sustainable industrialization and foster innovation.',
    'SDG 10': 'Reduced Inequalities: Reduce inequality within and among countries.',
    'SDG 11': 'Sustainable Cities and Communities: Make cities and human settlements inclusive, safe, resilient and sustainable, urban planning.',
    'SDG 12': 'Responsible Consumption and Production: Ensure sustainable consumption and production patterns, waste management, recycling.',
    'SDG 13': 'Climate Action: Take urgent action to combat climate change and its impacts, global warming, carbon emission.',
    'SDG 14': 'Life Below Water: Conserve and sustainably use the oceans, seas and marine resources, marine biology.',
    'SDG 15': 'Life on Land: Protect, restore and promote sustainable use of terrestrial ecosystems, forests, biodiversity.',
    'SDG 16': 'Peace, Justice and Strong Institutions: Promote peaceful and inclusive societies, justice, law.',
    'SDG 17': 'Partnerships for the Goals: Strengthen the means of implementation and revitalize the global partnership.'
}

sdg_labels = list(sdg_definitions.keys())
sdg_texts = list(sdg_definitions.values())

# 3. Load AI Model (Sentence-BERT)
print("🤖 Loading AI Model (all-MiniLM-L6-v2)... This might take a minute.")
model = SentenceTransformer('all-MiniLM-L6-v2')

# 4. Encoding
print("⚙️ Embedding SDG Definitions...")
sdg_embeddings = model.encode(sdg_texts, convert_to_tensor=True)

print("⚙️ Embedding Research Titles (This identifies the meaning)...")
paper_embeddings = model.encode(df['title'].tolist(), convert_to_tensor=True, show_progress_bar=True)

# 5. Semantic Search
print("🔍 Matching Papers to SDGs...")

cosine_scores = util.cos_sim(paper_embeddings, sdg_embeddings)

top_results = torch.topk(cosine_scores, k=1, dim=1)
top_indices = top_results.indices.flatten().tolist()
top_scores = top_results.values.flatten().tolist()

df['Predicted SDG'] = [sdg_labels[i] for i in top_indices]
df['SDG Score'] = top_scores 

threshold = 0.25
df.loc[df['SDG Score'] < threshold, 'Predicted SDG'] = 'General / Non-SDG'

print("✅ Classification Complete!")
print(df['Predicted SDG'].value_counts().head())

# 6. Save
df.to_csv('chula_sdg_classified.csv', index=False)
print("💾 Saved to 'chula_sdg_classified.csv'")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# <>:13: SyntaxWarning: invalid escape sequence '\p'
# <>:22: SyntaxWarning: invalid escape sequence '\p'
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# <>:13: SyntaxWarning: invalid escape sequence '\p'
# <>:22: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\สึนามิ\AppData\Local\Temp\ipykernel_16796\1707001792.py:11: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('CSV_Files\papers_all_years.csv')
# C:\Users\สึนามิ\AppData\Local\Temp\ipykernel_16796\1707001792.py:13: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('CSV_Files\papers_all_years.csv')
# C:\Users\สึนามิ\AppData\Local\Temp\ipykernel_16796\1707001792.py:22: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('CSV_Files\papers_all_years.csv')
# C:\Users\สึนามิ\AppData\Local\Temp\ipykernel_16796\1707001792.py:11: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('CSV_Files\papers_all_years.csv')
# C:\Users\สึนามิ\AppData\Local\Temp\ipykernel_16796\1707001792.py:13: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('CSV_Files\papers_all_years.csv')
# C:\Users\สึนามิ\AppData\Local\Temp\ipykernel_16796\1707001792.py:22: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('CSV_Files\papers_all_years.csv')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sentence_transformers import SentenceTransformer, util
#       4 import torch
#       6 print("🚀 Starting SDG Classification (Unsupervised AI)...")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sentence_transformers\backend\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
#       5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sentence_transformers\backend\load.py:7
#       4 import logging
#       5 from pathlib import Path
# ----> 7 from transformers.configuration_utils import PretrainedConfig
#       9 from sentence_transformers.backend.utils import _save_pretrained_wrapper, backend_should_export, backend_warn_to_save
#      11 logger = logging.getLogger(__name__)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\__init__.py:24
#      21 from packaging import version
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#      27     ImageProcessorArgs,
#      28     ModelArgs,
#      29     ModelOutputArgs,
#      30     auto_class_docstring,
#      31     auto_docstring,
#      32     get_args_doc_from_source,
#      33     parse_docstring,
#      34     set_min_indent,
#      35 )
#      36 from .backbone_utils import BackboneConfigMixin, BackboneMixin
#      37 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\auto_docstring.py:30
#      22 import regex as re
#      24 from .doc import (
#      25     MODELS_TO_PIPELINE,
#      26     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      27     PT_SAMPLE_DOCSTRINGS,
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      33 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      36 AUTODOC_FILES = [
#      37     "configuration_*.py",
#      38     "modeling_*.py",
#    (...)
#      43     "feature_extractor_*.py",
#      44 ]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\generic.py:51
#      47 logger = logging.get_logger(__name__)
#      49 if is_torch_available():
#      50     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 51     import torch
#      53     from ..model_debugging_utils import model_addition_debugger_context
#      56 # vendored from distutils.util
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "C:\Users\สึนามิ\AppData\Roaming\Python\Python312\site-packages\torch\lib\c10.dll" or one of its dependencies.
